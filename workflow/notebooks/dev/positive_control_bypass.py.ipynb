# %%
import os, sys
import pandas as pd
import scipy

pd.options.display.max_rows = 100
# LOAD MOSAIC COUNTS INFO
# counts = snakemake.input.counts
# counts_df = pd.read_csv(counts, sep="\t", compression="gzip")
# counts_df["cell"] = counts_df["cell"] + ".sort.mdup.bam"

# # Groupby cell & sum reads
# counts_gb_df = counts_df.groupby("cell")[["c", "w"]].sum()
# counts_gb_df["nb_reads"] = counts_gb_df["c"] + counts_gb_df["w"]
# info = snakemake.input.info
info = "/scratch/tweber/DATA/MC_DATA/EVA_1511_H33JMAFX5/KM1096/counts/KM1096.info_raw"
info_df = pd.read_csv(info, sep="\t", skiprows=13)
info_df["cell"] = info_df["cell"] + ".sort.mdup.bam"

# Load ashleys predictions
# labels = pd.read_csv(directory + "/cell_selection/labels_raw.tsv".format(sample=sample), sep="\t").sort_values(by="cell")
# labels_path = snakemake.input.labels
labels_path = "/scratch/tweber/DATA/MC_DATA/EVA_1511_H33JMAFX5/KM1096/cell_selection/labels_raw.tsv"
labels = pd.read_csv(labels_path, sep="\t").sort_values(by="cell")
# labels["sample"] = sample
labels["sample"] = "KM1096"

# Retrieve correct prediction
# labels_corrected = labels.loc[labels["prediction"] == 1]

# Merge counts & labels
# labels_corrected = pd.merge(info_df.reset_index()[["cell", "good"]], labels_corrected, on="cell")
labels_corrected = pd.merge(info_df[["cell", "good"]], labels, on="cell")
# Compute z-score on reads nb
labels_corrected["z_score"] = scipy.stats.zscore(labels_corrected["good"])

# Output, Correct outliers predictions & proba
# labels_corrected.loc[labels_corrected["z_score"] >= 5, "cell"].to_csv(snakemake.output.bypass_cell, index=False, sep="\t")
labels_corrected.loc[labels_corrected["z_score"] >= 5, "new_prediction"] = 0
labels_corrected.loc[labels_corrected["z_score"] >= 5, "new_probability"] = 0
# labels_corrected.loc[labels_corrected["z_score"] < 5, "new_probability"] = labels_corrected.loc[
#     labels_corrected["z_score"] < 5, "probability"
# ]
labels_corrected["new_prediction"] = labels_corrected["new_prediction"].fillna(1)
labels_corrected["new_prediction"] = labels_corrected["new_prediction"].astype(int)

# Back to full dataframe
labels.loc[labels["cell"].isin(labels_corrected.cell.values.tolist()), "prediction"] = labels_corrected.new_prediction.values.tolist()
labels.loc[labels["cell"].isin(labels_corrected.cell.values.tolist()), "probability"] = labels_corrected.new_probability.values.tolist()
labels_corrected
# Output
# labels.to_csv(snakemake.output.labels_corrected, index=False, sep="\t")
# Out:
#                            cell     good  prediction  probability  sample  \
# 0   KM1096PE20301.sort.mdup.bam  1571556           0       0.3126  KM1096
# 1   KM1096PE20302.sort.mdup.bam   445923           0       0.0037  KM1096
# 2   KM1096PE20303.sort.mdup.bam   342943           0       0.3814  KM1096
# 3   KM1096PE20304.sort.mdup.bam    34113           0       0.0001  KM1096
# 4   KM1096PE20305.sort.mdup.bam   272073           1       0.9192  KM1096
# 5   KM1096PE20306.sort.mdup.bam     4925           0       0.0000  KM1096
# 6   KM1096PE20307.sort.mdup.bam   376161           1       0.9173  KM1096
# 7   KM1096PE20308.sort.mdup.bam   361599           1       0.9014  KM1096
# 8   KM1096PE20309.sort.mdup.bam   327949           1       0.8854  KM1096
# 9   KM1096PE20310.sort.mdup.bam   323280           1       0.9007  KM1096
# 10  KM1096PE20311.sort.mdup.bam   293426           1       0.9017  KM1096
# 11  KM1096PE20312.sort.mdup.bam   246388           1       0.9261  KM1096
# 12  KM1096PE20313.sort.mdup.bam   255110           1       0.9107  KM1096
# 13  KM1096PE20314.sort.mdup.bam   319140           1       0.9164  KM1096
# 14  KM1096PE20315.sort.mdup.bam   291156           1       0.9110  KM1096
# 15  KM1096PE20316.sort.mdup.bam   113866           0       0.4505  KM1096
# 16  KM1096PE20317.sort.mdup.bam   300012           0       0.0688  KM1096
# 17  KM1096PE20318.sort.mdup.bam   303223           1       0.8609  KM1096
# 18  KM1096PE20319.sort.mdup.bam   287430           1       0.9091  KM1096
# 19  KM1096PE20320.sort.mdup.bam   307557           1       0.9229  KM1096
# 20  KM1096PE20321.sort.mdup.bam   218165           1       0.8369  KM1096
# 21  KM1096PE20322.sort.mdup.bam   306353           1       0.8957  KM1096
# 22  KM1096PE20323.sort.mdup.bam   157373           0       0.0804  KM1096
# 23  KM1096PE20324.sort.mdup.bam   227062           1       0.8741  KM1096
# 24  KM1096PE20325.sort.mdup.bam    64674           0       0.1174  KM1096
# 25  KM1096PE20326.sort.mdup.bam   213668           1       0.6232  KM1096
# 26  KM1096PE20327.sort.mdup.bam   235817           1       0.9082  KM1096
# 27  KM1096PE20328.sort.mdup.bam   148175           1       0.8874  KM1096
# 28  KM1096PE20329.sort.mdup.bam   385754           1       0.8521  KM1096
# 29  KM1096PE20330.sort.mdup.bam   300911           1       0.8838  KM1096
# 30  KM1096PE20331.sort.mdup.bam   227924           1       0.9002  KM1096
# 31  KM1096PE20332.sort.mdup.bam   112685           1       0.7831  KM1096
# 32  KM1096PE20333.sort.mdup.bam   126153           1       0.8809  KM1096
# 33  KM1096PE20334.sort.mdup.bam   326878           1       0.9172  KM1096
# 34  KM1096PE20335.sort.mdup.bam   158922           0       0.2777  KM1096
# 35  KM1096PE20336.sort.mdup.bam   207199           1       0.9232  KM1096
# 36  KM1096PE20337.sort.mdup.bam   264069           0       0.0242  KM1096
# 37  KM1096PE20338.sort.mdup.bam   315482           1       0.5076  KM1096
# 38  KM1096PE20339.sort.mdup.bam   288646           1       0.8679  KM1096
# 39  KM1096PE20340.sort.mdup.bam   542517           0       0.0464  KM1096
# 40  KM1096PE20341.sort.mdup.bam   102943           0       0.4299  KM1096
# 41  KM1096PE20342.sort.mdup.bam    57894           0       0.0164  KM1096
# 42  KM1096PE20343.sort.mdup.bam    55653           0       0.0000  KM1096
# 43  KM1096PE20344.sort.mdup.bam   147320           1       0.8308  KM1096
# 44  KM1096PE20345.sort.mdup.bam   191253           1       0.8639  KM1096
# 45  KM1096PE20346.sort.mdup.bam   119493           0       0.4439  KM1096
# 46  KM1096PE20347.sort.mdup.bam   136510           0       0.0646  KM1096
# 47  KM1096PE20348.sort.mdup.bam   393872           0       0.0496  KM1096
# 48  KM1096PE20349.sort.mdup.bam   274595           1       0.9108  KM1096
# 49  KM1096PE20350.sort.mdup.bam    93402           1       0.5265  KM1096
# 50  KM1096PE20351.sort.mdup.bam   195850           0       0.0473  KM1096
# 51  KM1096PE20352.sort.mdup.bam    94098           0       0.0337  KM1096
# 52  KM1096PE20353.sort.mdup.bam   288624           1       0.9209  KM1096
# 53  KM1096PE20354.sort.mdup.bam   268816           1       0.5000  KM1096
# 54  KM1096PE20355.sort.mdup.bam   156645           1       0.9322  KM1096
# 55  KM1096PE20356.sort.mdup.bam   246112           1       0.5219  KM1096
# 56  KM1096PE20357.sort.mdup.bam   126745           1       0.9339  KM1096
# 57  KM1096PE20358.sort.mdup.bam    90197           0       0.0175  KM1096
# 58  KM1096PE20359.sort.mdup.bam   281382           0       0.3645  KM1096
# 59  KM1096PE20360.sort.mdup.bam   420203           1       0.8846  KM1096
# 60  KM1096PE20361.sort.mdup.bam   315342           1       0.9277  KM1096
# 61  KM1096PE20362.sort.mdup.bam   234903           1       0.9393  KM1096
# 62  KM1096PE20363.sort.mdup.bam   245364           1       0.8129  KM1096
# 63  KM1096PE20364.sort.mdup.bam   419194           1       0.9184  KM1096
# 64  KM1096PE20365.sort.mdup.bam    97045           0       0.3957  KM1096
# 65  KM1096PE20366.sort.mdup.bam   234205           1       0.9183  KM1096
# 66  KM1096PE20367.sort.mdup.bam   253133           1       0.9023  KM1096
# 67  KM1096PE20368.sort.mdup.bam   333444           1       0.8978  KM1096
# 68  KM1096PE20369.sort.mdup.bam    76928           0       0.0094  KM1096
# 69  KM1096PE20370.sort.mdup.bam   401186           1       0.8857  KM1096
# 70  KM1096PE20371.sort.mdup.bam   247594           1       0.9048  KM1096
# 71  KM1096PE20372.sort.mdup.bam   559651           1       0.4675  KM1096
# 72  KM1096PE20373.sort.mdup.bam   172813           1       0.8821  KM1096
# 73  KM1096PE20374.sort.mdup.bam   281296           0       0.0054  KM1096
# 74  KM1096PE20375.sort.mdup.bam   265322           1       0.9099  KM1096
# 75  KM1096PE20376.sort.mdup.bam   232283           0       0.3340  KM1096
# 76  KM1096PE20377.sort.mdup.bam   444610           0       0.2375  KM1096
# 77  KM1096PE20378.sort.mdup.bam   286787           1       0.7415  KM1096
# 78  KM1096PE20379.sort.mdup.bam   246891           1       0.8608  KM1096
# 79  KM1096PE20380.sort.mdup.bam   461174           1       0.8815  KM1096
# 80  KM1096PE20381.sort.mdup.bam    87477           1       0.7548  KM1096
# 81  KM1096PE20382.sort.mdup.bam   200938           1       0.8663  KM1096
# 82  KM1096PE20383.sort.mdup.bam   538203           1       0.8364  KM1096
# 83  KM1096PE20384.sort.mdup.bam   147534           1       0.8848  KM1096
# 84  KM1096PE20385.sort.mdup.bam   192276           1       0.8642  KM1096
# 85  KM1096PE20386.sort.mdup.bam    36598           0       0.0000  KM1096
# 86  KM1096PE20387.sort.mdup.bam   269541           0       0.0093  KM1096
# 87  KM1096PE20388.sort.mdup.bam   917024           0       0.2119  KM1096
# 88  KM1096PE20389.sort.mdup.bam    32084           0       0.0000  KM1096
# 89  KM1096PE20390.sort.mdup.bam   279607           1       0.8947  KM1096
# 90  KM1096PE20391.sort.mdup.bam    94941           1       0.7477  KM1096
# 91  KM1096PE20392.sort.mdup.bam   507228           0       0.4342  KM1096
# 92  KM1096PE20393.sort.mdup.bam   409190           1       0.8864  KM1096
# 93  KM1096PE20394.sort.mdup.bam   444549           1       0.8102  KM1096
# 94  KM1096PE20395.sort.mdup.bam   239078           1       0.9000  KM1096
# 95  KM1096PE20396.sort.mdup.bam      496           0       0.0000  KM1096
#
#      z_score  new_prediction  new_probability
# 0   6.690767               0              0.0
# 1   0.921258               1              NaN
# 2   0.393427               1              NaN
# 3  -1.189503               1              NaN
# 4   0.030178               1              NaN
# 5  -1.339108               1              NaN
# 6   0.563688               1              NaN
# 7   0.489049               1              NaN
# 8   0.316574               1              NaN
# 9   0.292643               1              NaN
# 10  0.139624               1              NaN
# 11 -0.101473               1              NaN
# 12 -0.056767               1              NaN
# 13  0.271423               1              NaN
# 14  0.127989               1              NaN
# 15 -0.780723               1              NaN
# 16  0.173381               1              NaN
# 17  0.189839               1              NaN
# 18  0.108891               1              NaN
# 19  0.212053               1              NaN
# 20 -0.246132               1              NaN
# 21  0.205882               1              NaN
# 22 -0.557725               1              NaN
# 23 -0.200529               1              NaN
# 24 -1.032860               1              NaN
# 25 -0.269181               1              NaN
# 26 -0.155655               1              NaN
# 27 -0.604870               1              NaN
# 28  0.612857               1              NaN
# 29  0.177989               1              NaN
# 30 -0.196111               1              NaN
# 31 -0.786777               1              NaN
# 32 -0.717745               1              NaN
# 33  0.311084               1              NaN
# 34 -0.549786               1              NaN
# 35 -0.302339               1              NaN
# 36 -0.010847               1              NaN
# 37  0.252673               1              NaN
# 38  0.115124               1              NaN
# 39  1.416357               1              NaN
# 40 -0.836710               1              NaN
# 41 -1.067612               1              NaN
# 42 -1.079098               1              NaN
# 43 -0.609252               1              NaN
# 44 -0.384071               1              NaN
# 45 -0.751882               1              NaN
# 46 -0.664660               1              NaN
# 47  0.654467               1              NaN
# 48  0.043104               1              NaN
# 49 -0.885613               1              NaN
# 50 -0.360509               1              NaN
# 51 -0.882045               1              NaN
# 52  0.115011               1              NaN
# 53  0.013484               1              NaN
# 54 -0.561457               1              NaN
# 55 -0.102887               1              NaN
# 56 -0.714711               1              NaN
# 57 -0.902040               1              NaN
# 58  0.077892               1              NaN
# 59  0.789428               1              NaN
# 60  0.251956               1              NaN
# 61 -0.160340               1              NaN
# 62 -0.106721               1              NaN
# 63  0.784256               1              NaN
# 64 -0.866940               1              NaN
# 65 -0.163917               1              NaN
# 66 -0.066901               1              NaN
# 67  0.344739               1              NaN
# 68 -0.970051               1              NaN
# 69  0.691955               1              NaN
# 70 -0.095291               1              NaN
# 71  1.504178               1              NaN
# 72 -0.478586               1              NaN
# 73  0.077451               1              NaN
# 74 -0.004425               1              NaN
# 75 -0.173769               1              NaN
# 76  0.914528               1              NaN
# 77  0.105595               1              NaN
# 78 -0.098894               1              NaN
# 79  0.999428               1              NaN
# 80 -0.915982               1              NaN
# 81 -0.334430               1              NaN
# 82  1.394245               1              NaN
# 83 -0.608156               1              NaN
# 84 -0.378827               1              NaN
# 85 -1.176766               1              NaN
# 86  0.017200               1              NaN
# 87  3.335918               1              NaN
# 88 -1.199902               1              NaN
# 89  0.068794               1              NaN
# 90 -0.877725               1              NaN
# 91  1.235481               1              NaN
# 92  0.732980               1              NaN
# 93  0.914215               1              NaN
# 94 -0.138941               1              NaN
# 95 -1.361809               1              NaN
